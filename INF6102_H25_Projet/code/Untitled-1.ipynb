# %%
Instances = ['instance A', 'instance B', 'instance C', 'instance D', 'instance E', 'instance complet']
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ***********************************************************
# [INFO] Start the solving Eternity II
# [INFO] input file: ./INF6102_H25_Projet/code/instances/eternity_A.txt
# [INFO] output file: solution.txt
# [INFO] visualization file: visualization.png
# [INFO] board size: 4 x 4
# [INFO] solver selected: heuristic
# ***********************************************************
# Best score : 0, score moyen : 4.52
# times_exec : 0.0028601932525634767
# ***********************************************************
# [INFO] Solution obtained
# [INFO] Execution time: 0.0 minutes
# [INFO] Number of conflicts: 0
# [INFO] Feasible solution: True
# [INFO] Sanity check passed: True
# ***********************************************************
# ***********************************************************
# [INFO] Start the solving Eternity II
# [INFO] input file: ./INF6102_H25_Projet/code/instances/eternity_B.txt
# [INFO] output file: solution.txt
# [INFO] visualization file: visualization.png
# [INFO] board size: 7 x 7
# [INFO] solver selected: heuristic
# ***********************************************************
# Best score : 12, score moyen : 18.12
# times_exec : 0.023676047325134276
# ***********************************************************
# [INFO] Solution obtained
# [INFO] Execution time: 0.0 minutes
# [INFO] Number of conflicts: 17
# [INFO] Feasible solution: False
# [INFO] Sanity check passed: True
# ***********************************************************
# ***********************************************************
# [INFO] Start the solving Eternity II
# [INFO] input file: ./INF6102_H25_Projet/code/instances/eternity_C.txt
# [INFO] output file: solution.txt
# [INFO] visualization file: visualization.png
# [INFO] board size: 8 x 8
# [INFO] solver selected: heuristic
# ***********************************************************
# Best score : 21, score moyen : 28.84
# times_exec : 0.04262094020843506
# ***********************************************************
# [INFO] Solution obtained
# [INFO] Execution time: 0.0 minutes
# [INFO] Number of conflicts: 30
# [INFO] Feasible solution: False
# [INFO] Sanity check passed: True
# ***********************************************************
# ***********************************************************
# [INFO] Start the solving Eternity II
# [INFO] input file: ./INF6102_H25_Projet/code/instances/eternity_D.txt
# [INFO] output file: solution.txt
# [INFO] visualization file: visualization.png
# [INFO] board size: 9 x 9
# [INFO] solver selected: heuristic
# ***********************************************************
# Best score : 26, score moyen : 34.28
# times_exec : 0.06892624855041504
# ***********************************************************
# [INFO] Solution obtained
# [INFO] Execution time: 0.0 minutes
# [INFO] Number of conflicts: 34
# [INFO] Feasible solution: False
# [INFO] Sanity check passed: True
# ***********************************************************
# ***********************************************************
# [INFO] Start the solving Eternity II
# [INFO] input file: ./INF6102_H25_Projet/code/instances/eternity_E.txt
# [INFO] output file: solution.txt
# [INFO] visualization file: visualization.png
# [INFO] board size: 10 x 10
# [INFO] solver selected: heuristic
# ***********************************************************
# Best score : 29, score moyen : 38.48
# times_exec : 0.09779057025909424
# ***********************************************************
# [INFO] Solution obtained
# [INFO] Execution time: 0.0 minutes
# [INFO] Number of conflicts: 38
# [INFO] Feasible solution: False
# [INFO] Sanity check passed: True
# ***********************************************************
# ***********************************************************
# [INFO] Start the solving Eternity II
# [INFO] input file: ./INF6102_H25_Projet/code/instances/eternity_complet.txt
# [INFO] output file: solution.txt
# [INFO] visualization file: visualization.png
# [INFO] board size: 16 x 16
# [INFO] solver selected: heuristic
# ***********************************************************
# Best score : 83, score moyen : 97.4
# times_exec : 0.6122608327865601
# ***********************************************************
# [INFO] Solution obtained
# [INFO] Execution time: 0.01 minutes
# [INFO] Number of conflicts: 94
# [INFO] Feasible solution: False
# [INFO] Sanity check passed: True
# ***********************************************************
